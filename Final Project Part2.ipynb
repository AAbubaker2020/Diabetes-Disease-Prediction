# %% [markdown]
# ## 1- Title
# ##                                       Final Project Part2
# ##                               Diabetes Disease Prediction
#
# ## Name: Abubaker Ahmed

# %% [markdown]
# ## 2- Exploratory Data Analysis (EDA)

# %% [markdown]
# ## First checking the database if it is has any missing data

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read the dataset to datafram using pd.read_csv() because our dataset is a csv file.

# %%
Diabetes_df = pd.read_csv("C:/Users/aabub\Downloads/diabetes_012_health_indicators_BRFSS2015.csv")

# %% [markdown]
# ### Check the first five rows of our Diabetes_df

# %%
Diabetes_df.head()
# Out:
#    Diabetes_012  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0             0       1         1          1   40       1       0
# 1             0       0         0          0   25       1       0
# 2             0       1         1          1   28       0       0
# 3             0       1         0          1   27       0       0
# 4             0       1         1          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  Fruits  ...  AnyHealthcare  \
# 0                     0             0       0  ...              1
# 1                     0             1       0  ...              0
# 2                     0             0       1  ...              1
# 3                     0             1       1  ...              1
# 4                     0             1       1  ...              1
#
#    NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  \
# 0            0        5        18        15         1    0    9          4
# ...

# %% [markdown]
# ### Checking if our dataset has any null values in each of the columns and how many of nulls it has

# %%
Diabetes_df.isna().sum()
# Out:
# Diabetes_012            0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# HeartDiseaseorAttack    0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# dtype: int64

# %%
Diabetes_df.dtypes
# Out:
# Diabetes_012            int64
# HighBP                  int64
# HighChol                int64
# CholCheck               int64
# BMI                     int64
# Smoker                  int64
# Stroke                  int64
# HeartDiseaseorAttack    int64
# PhysActivity            int64
# Fruits                  int64
# Veggies                 int64
# HvyAlcoholConsump       int64
# AnyHealthcare           int64
# NoDocbcCost             int64
# GenHlth                 int64
# MentHlth                int64
# PhysHlth                int64
# DiffWalk                int64
# Sex                     int64
# Age                     int64
# Education               int64
# Income                  int64
# dtype: object

# %% [markdown]
# ### After performing the quirey it showed the dataset has zero null value which a great starting point

# %% [markdown]
# ### Visualizing Diabetes data in One Dimension (1-D)

# %%
Diabetes_df.hist(bins=15, color='steelblue', edgecolor='black', linewidth=1.0,
           xlabelsize=8, ylabelsize=8, grid=False)    
plt.tight_layout(rect=(0, 0, 1.5, 1.5)) 
plt.title("Visualizing attributes as one-dimensional data")
# Out:
# Text(0.5, 1.0, 'Visualizing attributes as one-dimensional data')

# %% [markdown]
# ### Visualizing Diabetes data in Two Dimensions (2-D)

# %%
# Correlation Matrix Heatmap
f, ax = plt.subplots(figsize=(15, 8))
corr = Diabetes_df.corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
f.subplots_adjust(top=0.93)
t= f.suptitle('Diabetes Attributes Correlation Heatmap', fontsize=14)

# %% [markdown]
# ### Visualizing Diabetes data in Three Dimensions (3-D)

# %% [markdown]
# #### I will demonstrate some of the chosen features for (3-D Visualization)

# %%
# Visualizing 3-D numeric data with Scatter Plots
# length, breadth and depth for some of the choosen featuers
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = Diabetes_df['HighChol']
ys = Diabetes_df['BMI']
zs = Diabetes_df['Diabetes_012']
ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('HighChol')
ax.set_ylabel('BMI')
ax.set_zlabel('Diabetes_012')
# Out:
# Text(0.5, 0, 'Diabetes_012')

# %%
# Visualizing 3-D numeric data with Scatter Plots
# length, breadth and depth
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = Diabetes_df['GenHlth']
ys = Diabetes_df['Sex']
zs = Diabetes_df['Diabetes_012']
ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('HighChol')
ax.set_ylabel('BMI')
ax.set_zlabel('Diabetes_012')
# Out:
# Text(0.5, 0, 'Diabetes_012')

# %%
# Visualizing 3-D numeric data with Scatter Plots
# length, breadth and depth
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = Diabetes_df['Age']
ys = Diabetes_df['Sex']
zs = Diabetes_df['Diabetes_012']
ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('HighChol')
ax.set_ylabel('BMI')
ax.set_zlabel('Diabetes_012')
# Out:
# Text(0.5, 0, 'Diabetes_012')

# %%
# Scatter Plot with Hue for visualizing data in 3-D
cols = ['Diabetes_012', 'HighBP', 'HighChol', 'BMI', 'GenHlth', 'Sex', 'Age', 'Education']
pp = sns.pairplot(Diabetes_df[cols], hue_order = 'Sex', size=1.8, aspect=1.8, 
                  palette={"red": "#FF9999", "white": "#FFE888"},
                  plot_kws=dict(edgecolor="black", linewidth=0.5))

fig = pp.fig 
fig.subplots_adjust(top=0.93, wspace=0.3)
t = fig.suptitle('Diabetes Attributes Pairwise Plots', fontsize=14)
# Out:
# C:\Users\aabub\.conda\envs\ds\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 3- Unsupervised techniques or Supervised techniques

# %% [markdown]
# ### 1- Interdependency techniques

# %% [markdown]
# #### Import necessary libraries

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from matplotlib import pyplot
from numpy import unique
from numpy import where

# %% [markdown]
# ### Preparing Data for Plotting

# %%
pca = PCA(2)

# %%
df = pca.fit_transform(Diabetes_df)
df.shape
# Out:
# (253680, 2)

# %% [markdown]
# ### Diabetes_df contains dataset of size 253680 x 22 . I used PCA to reduce the number of dimensions so that we can visualize the results using a 2D Scatter plot.

# %% [markdown]
# ###  Apply K-Means clustering algorithm to the Data

# %% [markdown]
# #### Now, I will apply K-mean to our data to create the difference clusters. Here in the Diabetes_df dataset I already know that the labels range from 0 to 2, so we have 3 classes (or clusters) for Diabetes which is Diabete, Pre_Diabetes_df or No Diabetes (0, 1, 2)

# %%
X = Diabetes_df

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=20,alpha=0.5)
plt.title("Diabetes_df three different clusters")
# Out:
# Text(0.5, 1.0, 'Diabetes_df three different clusters')

# %% [markdown]
# ### 2- Dependency techniques

# %% [markdown]
# #### Import necessary libraries

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### I will divied the the dataset into features and target variable

# %%
X = Diabetes_df.drop("Diabetes_012",axis=1)

# %%
y = Diabetes_df["Diabetes_012"]

# %%
print( " shape of X is: ",X.shape, " shape of y is: ", y.shape)
# Out:
#  shape of X is:  (253680, 21)  shape of y is:  (253680,)

# %% [markdown]
# #### I will use train_test_split to split the data to 80  % training data and 20 % test data

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=142)

# %% [markdown]
# #### define the knn model and fit the knn model

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# #### I will use the X_test data to predict class through the model

# %%
prediction_results = knn.predict(X_test.iloc[:1,:])
print(prediction_results)
# Out:
# [0]

# %% [markdown]
# #### By checking the y_test[:1] to make sure the model classfiy the correct result.

# %%
print(y_test[:1])
# Out:
# 210505    0
# Name: Diabetes_012, dtype: int64

# %% [markdown]
# #### from the real value of y_test[:1] the model predict the correct result

# %% [markdown]
# ######

# %% [markdown]
# #### I will Check the knn model accuracy by using accuracy_score

# %%
y_pred = knn.predict(X_test)

# %% [markdown]
# .

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8202262693156733

# %% [markdown]
# #### The knn model accuracy I got around 82%

# %% [markdown]
# ## 4. Main functionality

# %% [markdown]
# #### The Main functionality of my project is to predict weather the person is diabetes, prediabetes, or no diabetes, after checking my dataset and divided to features & target or labels I can use Supervised Learning techniques “multiple liner regression” to predict the label of future data entered by future users
# #### Note: my whole features data is a numeric and my target also a numeric 0 is for no diabetes or only during pregnancy, 1 is for prediabetes, and 2 is for diabetes

# %% [markdown]
# #### Import necessary libraries

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
import statsmodels.api as sm

# %% [markdown]
# #### Create and fit a linear regression model

# %%
# creating a regression model
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# making predictions
predictions = model.predict(X_test)

# %% [markdown]
# #### Evaluate the model with metrics.

# %%
# model evaluation
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  0.40226897591853356
# mean_absolute_error :  0.4430530693869811

# %%
print('Intercept: \n', model.intercept_)
print('Coefficients: \n', model.coef_)
# Out:
# Intercept:
#  -0.6055470429207326
# Coefficients:
#  [ 1.56234004e-01  1.20251627e-01  9.19932868e-02  1.44994273e-02
#  -1.38761111e-02  7.29665737e-02  1.30939615e-01 -1.12282191e-02
#  -1.26593040e-03 -8.03891921e-03 -1.02653113e-01  3.00132116e-02
#  -6.21625554e-03  9.85547451e-02 -1.37759628e-03  3.94370107e-05
#   8.86943766e-02  3.24760957e-02  1.56441877e-02 -8.09074381e-03
#  -1.45777202e-02]

# %%
model = sm.OLS(y, x).fit()
predictions = model.predict(x)

# %%
print_model = model.summary()
print(print_model)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:           Diabetes_012   R-squared (uncentered):                   0.294
# Model:                            OLS   Adj. R-squared (uncentered):              0.294
# Method:                 Least Squares   F-statistic:                              5024.
# Date:                Tue, 25 Oct 2022   Prob (F-statistic):                        0.00
# Time:                        22:53:11   Log-Likelihood:                     -2.4578e+05
# No. Observations:              253680   AIC:                                  4.916e+05
# Df Residuals:                  253659   BIC:                                  4.918e+05
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## 5- Personal Contribution Statement

# %% [markdown]
# #### I am doing an individual project and I managed to give it from 10 - 15 hours weekly to cover project part requirements and how it is been part from the whole project idea target also I put on mind any extra time need it depend on the task I am planning to be covered
# #### Since I am using Supervised Learning techniques “multiple liner regression” to predict weather the person diabetes disease, prediabetes, or no diabetes, I will try to do my best to improve the model accuracy by using cross-validation and KFold techniques to improve the model accuracy
#
# #### I use try to use dimensionality reductionto techniques to choose less features that has less correlation and more variance improve model accuracy
